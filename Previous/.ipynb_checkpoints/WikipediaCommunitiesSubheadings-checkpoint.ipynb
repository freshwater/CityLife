# %% [markdown]
# docker run -d --name sparkbook -p 8881:8888 -v "$PWD":/home/jovyan/work jupyter/pyspark-notebook start.sh jupyter lab --LabApp.token=''

# %% [markdown]
# m5.8xlarge  128GiB
# r5.4xlarge  128GiB
# x1e.xlarge  122GiB
# x1.16xlarge 976GiB
# i3.4xlarge  122GiB

# %%
import requests
from bs4 import BeautifulSoup
import pyspark as ps
import numpy as np
import time

response_cache = {}

def http_get(url):
    if response := response_cache.get(url):
        return response
    else:
        response = requests.request(url=url, method="GET")
        counties_list_html = response.content
        response_cache[url] = counties_list_html
        
        return response_cache[url]

spark = (ps.sql.SparkSession
         .builder
         .master('local[8]')
         .appName('lecture')
         .getOrCreate())

sc = spark.sparkContext

# %%
counties_list_url = "https://en.wikipedia.org/wiki/List_of_United_States_counties_and_county_equivalents"

def wikipedia_export_get(title):
    xml = http_get("https://en.wikipedia.org/wiki/Special:Export/" + title)
    
    if b'<redirect title' in xml:
        return wikipedia_export_get(title=BeautifulSoup(xml).select('redirect')[0]['title'])
    else:
        return xml

def wikipedia_standard_url(title):
    return "https://en.wikipedia.org/wiki/" + title

def wikipedia_counties_titles():
    soup = BeautifulSoup(http_get(counties_list_url))
    print(soup.select('.wikitable.sortable caption big'))
    
    rows = soup.select('.wikitable.sortable tbody tr')
    anchors = sum([row.select('td a')[:1] for row in rows], [])

    urls = [a['href'][len('/wiki/'):] for a in anchors]
    
    return urls
    
def wikipedia_communities_subheadings(text):
    import re

    regex = r"(^==Communities==)(.+?)(^==[^=].+?[^=]==)"
    post_communities = re.findall(regex, text, re.MULTILINE + re.DOTALL)
    
    if len(post_communities) == 0:
        return []

    # print(post_communities[0])
    post_communities = post_communities[0]
    
    regex = r"===(.+)==="
    res = [result.strip() for result in re.findall(regex, post_communities[1])]

    return res

time1 = time.time()
wikipedia_counties_titles()
f'time.{time.time() - time1}'
# Out:
# [<big>The 3,243 counties and county equivalents of the United States<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[c]</a></sup></big>]
# 'time.2.3139584064483643'

# %%
# Out:
# [<big>The 3,243 counties and county equivalents of the United States<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[c]</a></sup></big>]

# %% [markdown]
# ---

# %%
# %%time

twenty = wikipedia_counties_titles()

counties_export_text = (sc.parallelize(twenty)
                          .map(wikipedia_export_get)
                          .map(lambda export: BeautifulSoup(export).select('text')[0].getText())
                          .cache())
# Out:
# [<big>The 3,243 counties and county equivalents of the United States<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[c]</a></sup></big>]
# CPU times: user 2.07 s, sys: 17 ms, total: 2.09 s
# Wall time: 2.15 s

# %%
ls
# Out:
# Untitled1.ipynb

# %%
wikipedia_standard_url('Anchorage,_Alaska')
# Out:
# 'https://en.wikipedia.org/wiki/Anchorage,_Alaska'

# %% [markdown]
# Count empty subheadings

# %%
counties_export_text.count()
# Out:
# 3245

# %%
subs = counties_export_text.collect()
sum([set() == set(wikipedia_communities_subheadings(sub)) for title, sub in zip(twenty, subs)])
# Out:
# 586

# %%
counties_export_text.take(1000)
sorted([(wikipedia_standard_url(title), set(wikipedia_communities_subheadings(sub))) for title, sub in zip(twenty, subs)], key=lambda x: x[1])
# Out:
# [('https://en.wikipedia.org/wiki/Anchorage,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Bristol_Bay_Borough,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Haines_Borough,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Juneau,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Sitka,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Skagway,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Wrangell,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Yakutat,_Alaska', set()),
#  ('https://en.wikipedia.org/wiki/Eastern_District,_American_Samoa', set()),
#  ('https://en.wikipedia.org/wiki/Manu%27a_District,_American_Samoa', set()),
#  ('https://en.wikipedia.org/wiki/Rose_Atoll', set()),
#  ('https://en.wikipedia.org/wiki/Swains_Island', set()),
#  ('https://en.wikipedia.org/wiki/Western_District,_American_Samoa', set()),
#  ('https://en.wikipedia.org/wiki/Navajo_County,_Arizona', set()),
#  ('https://en.wikipedia.org/wiki/Cleveland_County,_Arkansas', set()),
#  ('https://en.wikipedia.org/wiki/Desha_County,_Arkansas', set()),
#  ('https://en.wikipedia.org/wiki/Johnson_County,_Arkansas', set()),
#  ('https://en.wikipedia.org/wiki/Woodruff_County,_Arkansas', set()),
#  ('https://en.wikipedia.org/wiki/San_Francisco', set()),
#  ('https://en.wikipedia.org/wiki/Sonoma_County,_California', set()),
#  ('https://en.wikipedia.org/wiki/Broomfield,_Colorado', set()),
#  ('https://en.wikipedia.org/wiki/Denver', set()),
#  ('https://en.wikipedia.org/wiki/Windham_County,_Connecticut', set()),
#  ('https://en.wikipedia.org/wiki/District_of_Columbia', set()),
#  ('https://en.wikipedia.org/wiki/Duval_County,_Florida', set()),
#  ('https://en.wikipedia.org/wiki/Miami-Dade_County,_Florida', set()),
#  ('https://en.wikipedia.org/wiki/Nassau_County,_Florida', set()),
#  ('https://en.wikipedia.org/wiki/Union_County,_Florida', set()),
#  ('https://en.wikipedia.org/wiki/Volusia_County,_Florida', set()),
#  ('https://en.wikipedia.org/wiki/Appling_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Banks_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Ben_Hill_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Bibb_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Brantley_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Bryan_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Bulloch_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Burke_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Butts_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Candler_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Carroll_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Charlton_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Chattahoochee_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Chattooga_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Clarke_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Clinch_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Cook_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Crisp_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Dade_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Dawson_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Dooly_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Echols_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Effingham_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Evans_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Fayette_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Glascock_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Gordon_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Greene_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Hancock_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Haralson_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Heard_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Jackson_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Jasper_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Johnson_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Jones_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Lamar_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Lee_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Lincoln_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Long_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Lumpkin_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Macon_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Madison_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Meriwether_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Miller_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Montgomery_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Newton_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Oconee_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Oglethorpe_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Paulding_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Peach_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Pickens_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Polk_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Pulaski_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Quitman_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Rabun_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Richmond_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Screven_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Seminole_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Stephens_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Stewart_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Sumter_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Taliaferro_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Terrell_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Toombs_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Towns_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Treutlen_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Troup_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Turner_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Twiggs_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Union_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Warren_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Webster_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Wheeler_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Wilkes_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Wilkinson_County,_Georgia', set()),
#  ('https://en.wikipedia.org/wiki/Guam', set()),
#  ('https://en.wikipedia.org/wiki/Hawaii_County,_Hawaii', set()),
#  ('https://en.wikipedia.org/wiki/Kalawao_County,_Hawaii', set()),
#  ('https://en.wikipedia.org/wiki/Minidoka_County,_Idaho', set()),
#  ('https://en.wikipedia.org/wiki/Teton_County,_Idaho', set()),
#  ('https://en.wikipedia.org/wiki/Twin_Falls_County,_Idaho', set()),
#  ('https://en.wikipedia.org/wiki/Carroll_County,_Illinois', set()),
#  ('https://en.wikipedia.org/wiki/Cumberland_County,_Illinois', set()),
#  ('https://en.wikipedia.org/wiki/Kankakee_County,_Illinois', set()),
#  ('https://en.wikipedia.org/wiki/Vermilion_County,_Illinois', set()),
#  ('https://en.wikipedia.org/wiki/Will_County,_Illinois', set()),
#  ('https://en.wikipedia.org/wiki/Allen_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Bartholomew_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Benton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Blackford_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Boone_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Brown_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Carroll_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Cass_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Clark_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Clay_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Clinton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Crawford_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Dearborn_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Decatur_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/DeKalb_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Delaware_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Dubois_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Fayette_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Floyd_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Fountain_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Fulton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Gibson_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Grant_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Greene_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Hamilton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Hancock_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Harrison_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Hendricks_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Henry_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Huntington_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Jackson_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Jasper_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Jay_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Jefferson_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Jennings_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Johnson_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Knox_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Kosciusko_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Lake_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/LaPorte_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Lawrence_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Madison_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Marion_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Montgomery_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Newton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Ohio_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Orange_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Owen_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Parke_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Perry_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Pike_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Porter_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Posey_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Pulaski_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Putnam_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Randolph_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Ripley_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Rush_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/St._Joseph_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Scott_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Shelby_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Spencer_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Starke_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Steuben_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Sullivan_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Switzerland_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Tipton_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Union_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Vanderburgh_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Vermillion_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Vigo_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Wabash_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Warren_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Warrick_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Wayne_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Wells_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/White_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Whitley_County,_Indiana', set()),
#  ('https://en.wikipedia.org/wiki/Greene_County,_Iowa', set()),
#  ('https://en.wikipedia.org/wiki/Gray_County,_Kansas', set()),
#  ('https://en.wikipedia.org/wiki/Autauga_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Baldwin_County,_Alabama',
#   {'Census-designated place',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated areas'}),
#  ('https://en.wikipedia.org/wiki/Barbour_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Bibb_County,_Alabama',
#   {'Cities', 'Ghost towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Blount_County,_Alabama',
#   {'Census-designated place',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Bullock_County,_Alabama',
#   {'Census-designated place',
#    'City',
#    'Ghost town',
#    'Town',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lowndes_County,_Alabama',
#   {'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Butler_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Calhoun_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Chambers_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cherokee_County,_Alabama',
#   {'Census-designated places',
#    'City',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Chilton_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Choctaw_County,_Alabama',
#   {'Census-designated place', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Perry_County,_Alabama',
#   {'Cities', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Clarke_County,_Alabama',
#   {'Census Designated Places',
#    'Cities',
#    'Former communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Clay_County,_Alabama',
#   {'Census-designated places', 'City', 'Town', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cleburne_County,_Alabama',
#   {'Census-designated place', 'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Coffee_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Colbert_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Conecuh_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Coosa_County,_Alabama',
#   {'Census-designated places', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Covington_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Crenshaw_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Fayette_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Henry_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lamar_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lee_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Limestone_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Pike_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cullman_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Dale_County,_Alabama',
#   {'Census-designated place',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Dallas_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/DeKalb_County,_Alabama',
#   {'Cities', 'Ghost towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Elmore_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Escambia_County,_Alabama',
#   {'Cities',
#    'Former town',
#    'Indian reservation',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Franklin_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Geneva_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Etowah_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Former city',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Greene_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Houston_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Macon_County,_Alabama',
#   {'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Hale_County,_Alabama',
#   {'City', 'Ghost towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Jackson_County,_Alabama',
#   {'Cities', 'Ghost towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Jefferson_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Former towns',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lauderdale_County,_Alabama',
#   {'Census-designated place', 'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lawrence_County,_Alabama',
#   {'Census Designated Places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Madison_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Marion_County,_Alabama',
#   {'Cities', 'Ghost town', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Pickens_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Marengo_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Marshall_County,_Alabama',
#   {'Census-designated place',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Shelby_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Sumter_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Mobile_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Randolph_County,_Alabama',
#   {'Census-designated places', 'City', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Monroe_County,_Alabama',
#   {'Census-designated places',
#    'City',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Montgomery_County,_Alabama',
#   {'City', 'Town', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Morgan_County,_Alabama',
#   {'Cities',
#    'Former city',
#    'Former town',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Russell_County,_Alabama',
#   {'Census-designated place',
#    'City',
#    'Former City',
#    'Town',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/St._Clair_County,_Alabama',
#   {'Cities', 'Former Towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Tallapoosa_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Talladega_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Tuscaloosa_County,_Alabama',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Walker_County,_Alabama',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Alabama',
#   {'Census-designated places',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wilcox_County,_Alabama',
#   {'Census-designated places',
#    'City',
#    'Ghost town',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Winston_County,_Alabama',
#   {'City', 'Ghost towns', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Aleutians_East_Borough,_Alaska',
#   {'Census-designated place', 'Cities', 'Other places'}),
#  ('https://en.wikipedia.org/wiki/Dillingham_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Lake_and_Peninsula_Borough,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Northwest_Arctic_Borough,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Southeast_Fairbanks_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Aleutians_West_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Military base'}),
#  ('https://en.wikipedia.org/wiki/Bethel_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Valdez%E2%80%93Cordova_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Other places'}),
#  ('https://en.wikipedia.org/wiki/Valdez%E2%80%93Cordova_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Other places'}),
#  ('https://en.wikipedia.org/wiki/Denali_Borough,_Alaska',
#   {'Census-designated places',
#    'City',
#    'Historical locations',
#    'Other unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Kodiak_Island_Borough,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Yukon%E2%80%93Koyukuk_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities'}),
#  ('https://en.wikipedia.org/wiki/Fairbanks_North_Star_Borough,_Alaska',
#   {'Census-designated places', 'Cities', 'Other unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Hoonah%E2%80%93Angoon_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Other unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Kenai_Peninsula_Borough,_Alaska',
#   {'Census-designated places', 'Cities', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ketchikan_Gateway_Borough,_Alaska',
#   {'Cities', 'Unincorporated Communities'}),
#  ('https://en.wikipedia.org/wiki/Kusilvak_Census_Area,_Alaska',
#   {'Census-designated place', 'Cities', 'Unincorporated Communities'}),
#  ('https://en.wikipedia.org/wiki/Matanuska-Susitna_Borough,_Alaska',
#   {'Census-designated places', 'Cities', 'Other locations'}),
#  ('https://en.wikipedia.org/wiki/Nome_Census_Area,_Alaska',
#   {'Cities', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/North_Slope_Borough,_Alaska',
#   {'Census-designated places', 'Cities', 'Other unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Petersburg_Borough,_Alaska',
#   {'Census-designated places', 'City'}),
#  ('https://en.wikipedia.org/wiki/Prince_of_Wales_%E2%80%93_Hyder_Census_Area,_Alaska',
#   {'Census-designated places', 'Cities', 'Unincorporated Community'}),
#  ('https://en.wikipedia.org/wiki/Apache_County,_Arizona',
#   {'Census-designated places',
#    'City',
#    'County population ranking',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cochise_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Military sites',
#    'Other places',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Coconino_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Indian reservations',
#    'Other communities',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Gila_County,_Arizona',
#   {'Census-designated places',
#    'City',
#    'County population ranking',
#    'Ghost towns',
#    'Indian communities',
#    'Other communities',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Graham_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Indian communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Greenlee_County,_Arizona',
#   {'Census-designated places',
#    'Ghost Towns',
#    'Other locations',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/La_Paz_County,_Arizona',
#   {'Census-designated places',
#    'County population ranking',
#    'Ghost towns',
#    'Indian communities',
#    'Towns',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Maricopa_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Native American communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Mohave_County,_Arizona',
#   {'Census designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Indian communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Pima_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost Towns in Pima County',
#    'Indian communities',
#    'Other communities',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Pinal_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Santa_Cruz_County,_Arizona',
#   {'=Ghost Towns=',
#    'Census designated places',
#    'Cities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Yavapai_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Geographic features',
#    'Ghost towns',
#    'Indian communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Yuma_County,_Arizona',
#   {'Census-designated places',
#    'Cities',
#    'County population ranking',
#    'Ghost towns',
#    'Indian reservations',
#    'Other unincorporated communities',
#    'Town'}),
#  ('https://en.wikipedia.org/wiki/Arkansas_County,_Arkansas',
#   {'=Historical communities=', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Dallas_County,_Arkansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Scott_County,_Arkansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Ashley_County,_Arkansas',
#   {'Census Designated Places',
#    'Cities',
#    'Historical communities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Bradley_County,_Arkansas',
#   {'Cities', 'Town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Baxter_County,_Arkansas',
#   {'Census designated place',
#    'Cities',
#    'Town',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Calhoun_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Benton_County,_Arkansas',
#   {'Census-designated places', 'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Boone_County,_Arkansas',
#   {'Cities',
#    'Historic communities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Carroll_County,_Arkansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Towns',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Chicot_County,_Arkansas',
#   {'Cities', 'Ghost town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Crittenden_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Faulkner_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Grant_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Lawrence_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Clark_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Clay_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Cleburne_County,_Arkansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Towns',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Columbia_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Cross_County,_Arkansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Conway_County,_Arkansas',
#   {'Census-designated place',
#    'Cities',
#    'Town',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Greene_County,_Arkansas',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Craighead_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Crawford_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Drew_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Fulton_County,_Arkansas',
#   {'Cities', 'Town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Franklin_County,_Arkansas',
#   {'Cities',
#    'Ghost towns',
#    'Town',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lafayette_County,_Arkansas',
#   {'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Lee_County,_Arkansas',
#   {'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Mississippi_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Monroe_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Pope_County,_Arkansas',
#   {'Cities', 'Towns', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/St._Francis_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Searcy_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Sebastian_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Arkansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Hempstead_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Union_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Garland_County,_Arkansas',
#   {'Census-designated places',
#    'Cities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Hot_Spring_County,_Arkansas',
#   {'Census Designated Place',
#    'Cities',
#    'Historical communities',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Howard_County,_Arkansas',
#   {'Cities', 'Historic communities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Independence_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Izard_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Jackson_County,_Arkansas',
#   {'Cities',
#    'Ghost towns',
#    'Towns',
#    'Townships',
#    'Unincorporated Communities'}),
#  ('https://en.wikipedia.org/wiki/Jefferson_County,_Arkansas',
#   {'Census-designated places',
#    'Cities',
#    'Historical towns',
#    'Other unincorporated communities',
#    'Towns',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Lincoln_County,_Arkansas',
#   {'Cities',
#    'Historical communities',
#    'Unincorporated communities',
#    '{{anchor|Auburn|Bartholomew|Cane Creek|Choctaw|Gould|Kimbrough|Lone Pine|Mill Creek|Owen|Smith|Spring|Wells Bayou}}Townships'}),
#  ('https://en.wikipedia.org/wiki/Lonoke_County,_Arkansas',
#   {'Census-designated place', 'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Nevada_County,_Arkansas',
#   {'Census-designated place', 'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Little_River_County,_Arkansas',
#   {'Census-designated place',
#    'Cities',
#    'Towns',
#    'Townships',
#    'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Logan_County,_Arkansas',
#   {'Census-designated place',
#    'Cities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Madison_County,_Arkansas',
#   {'City', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Marion_County,_Arkansas',
#   {'Cities', 'Town', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Miller_County,_Arkansas',
#   {'City',
#    'Historical communities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Montgomery_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Newton_County,_Arkansas',
#   {'City', 'Town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ouachita_County,_Arkansas',
#   {'Census designated place',
#    'Cities',
#    'Town',
#    'Townships',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Perry_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Phillips_County,_Arkansas',
#   {'Cities', 'Town', 'Townships', 'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Sevier_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Pike_County,_Arkansas',
#   {'Census designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Towns',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Poinsett_County,_Arkansas',
#   {'Cities', 'Town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Polk_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Stone_County,_Arkansas',
#   {'Cities',
#    'Historical communities',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Prairie_County,_Arkansas',
#   {'Cities',
#    'Historical communities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Pulaski_County,_Arkansas',
#   {'Census-designated places',
#    'Cities',
#    'Other communities',
#    'Town',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Randolph_County,_Arkansas',
#   {'Cities',
#    'Historical communities',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Saline_County,_Arkansas',
#   {'Census-designated places',
#    'Cities',
#    'Town',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Sharp_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Van_Buren_County,_Arkansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Towns',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Yell_County,_Arkansas',
#   {'Cities', 'Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/White_County,_Arkansas',
#   {'Cities',
#    'Historic towns',
#    'Towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Alpine_County,_California',
#   {'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Mono_County,_California',
#   {'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Merced_County,_California',
#   {'Census-designated places', 'Cities', 'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/San_Luis_Obispo_County,_California',
#   {'Cities', 'Population ranking', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Trinity_County,_California',
#   {'Census-designated places',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Amador_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Fresno_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Shasta_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Alameda_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former townships',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Butte_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Population ranking',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Calaveras_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former settlements',
#    'Other communities',
#    'Population ranking',
#    'Special districts'}),
#  ('https://en.wikipedia.org/wiki/Colusa_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Contra_Costa_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former communities',
#    'Ghost towns',
#    'Other places',
#    'Population ranking',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Del_Norte_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/El_Dorado_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Glenn_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Inyo_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Humboldt_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Indian reservations',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Mariposa_County,_California',
#   {'Census-designated places',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lake_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Madera_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Imperial_County,_California',
#   {'Area codes',
#    'Census-designated places',
#    'Cities',
#    'Former settlements',
#    'Indian Reservations',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Kern_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former places',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Kings_County,_California',
#   {'Census-designated places',
#    'Formerly proposed new city',
#    'Incorporated cities',
#    'Native American Reservation',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lassen_County,_California',
#   {'Census-designated places',
#    'City',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Los_Angeles_County,_California',
#   {'=Census designated places=',
#    '=Proposed Communities=',
#    '=Unincorporated Communities=',
#    'Cities',
#    'Population ranking',
#    'Unincorporated areas'}),
#  ('https://en.wikipedia.org/wiki/Marin_County,_California',
#   {'Census-designated places',
#    'Cities and towns',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Mendocino_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Indian reservations',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Modoc_County,_California',
#   {'Census-designated places',
#    'City',
#    'Other unincorporated places',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Monterey_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other places',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Napa_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Nevada_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Other unincorporated communities',
#    'Population ranking',
#    'Town'}),
#  ('https://en.wikipedia.org/wiki/Orange_County,_California',
#   {'Cities', 'Planned communities', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Placer_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Other communities',
#    'Population ranking',
#    'Towns'}),
#  ('https://en.wikipedia.org/wiki/Plumas_County,_California',
#   {'Census-designated places',
#    'City',
#    'Ghost towns',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Riverside_County,_California',
#   {'Cities',
#    'Ghost towns',
#    'Indian reservations',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Sacramento_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former townships',
#    'Population ranking',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Ventura_County,_California',
#   {'Cities', 'Population ranking', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/San_Joaquin_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Santa_Barbara_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/San_Benito_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/San_Bernardino_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Indian Reservations',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/San_Diego_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former cities',
#    'Indian reservations',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/San_Mateo_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Towns',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Santa_Clara_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Former townships',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Santa_Cruz_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Tuolumne_County,_California',
#   {'Census-designated places',
#    'City',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Sierra_County,_California',
#   {'Census-designated places',
#    'City',
#    'Ghost towns',
#    'Population ranking',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Solano_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Siskiyou_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Stanislaus_County,_California',
#   {'Census-designated places',
#    'Incorporated cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Sutter_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Proposed town',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Tehama_County,_California',
#   {'Census-designated places', 'Cities', 'Other unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Tulare_County,_California',
#   {'Census designated places',
#    'Cities',
#    'Indian reservation',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Yolo_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Yuba_County,_California',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Population ranking'}),
#  ('https://en.wikipedia.org/wiki/Adams_County,_Colorado',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Town'}),
#  ('https://en.wikipedia.org/wiki/Alamosa_County,_Colorado',
#   {'City', 'Town', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Arapahoe_County,_Colorado',
#   {'Census-designated places',
#    'Cities',
#    'Former Census-designated places',
#    'Towns'}),
# ...
#   {'Census-designated place',
#    'Cities',
#    'Population ranking',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Scott_County,_Iowa',
#   {'=Former township=',
#    'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Population ranking',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Shelby_County,_Iowa',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated places',
#    'Population ranking',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Taylor_County,_Iowa',
#   {'Census-designated place', 'Cities', 'Population ranking', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Allen_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Atchison_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Bourbon_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Chautauqua_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cloud_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Coffey_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Cowley_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wapello_County,_Iowa',
#   {'Cities', 'Population ranking', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Warren_County,_Iowa',
#   {'Cities', 'Population ranking', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Iowa',
#   {'Cities', 'Population ranking', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Woodbury_County,_Iowa',
#   {'Cities', 'Population ranking', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wright_County,_Iowa',
#   {'Cities', 'Population ranking', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Union_County,_Iowa',
#   {'Census-designated place',
#    'Cities',
#    'Population ranking',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Van_Buren_County,_Iowa',
#   {'Census-designated places',
#    'Cities',
#    'Population ranking',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wayne_County,_Iowa',
#   {'Cities',
#    'Ghost town',
#    'Population ranking',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Webster_County,_Iowa',
#   {'Census-designated place',
#    'Cities',
#    'Population ranking',
#    "Townships<ref>{{cite web|last1=Bony|first1=Jan|title=Webster County  IAGenWeb|url=http://iagenweb.org/webster/city-town.html|accessdate=July 25, 2014}}</ref><ref>{{cite web|title=Highway and Transportation Map, Webster County, Iowa|url=http://iagenweb.org/webster/maps/2008_Webster.pdf|accessdate=November 6, 2014 |publisher=IAGenWeb}}</ref><ref>{{cite web|title=SUMMARY REPORT, WEBSTER COUNTY, IOWA, UNOFFICIAL RESULTS, 2014 GENERAL ELECTION|url=http://www.webstercountyia.org/Auditor/Elections/2014General/SUMMARY.HTM|accessdate=November 6, 2014 |publisher=Webster County Auditor's Office}}</ref>",
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Worth_County,_Iowa',
#   {'Census-designated place', 'Cities', 'Population ranking', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Winneshiek_County,_Iowa',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Population ranking',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Anderson_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Barber_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Barton_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Brown_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Butler_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated places',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Chase_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Cherokee_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Ghost town',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Comanche_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Cheyenne_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Clark_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Clay_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Crawford_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated places',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Franklin_County,_Kansas',
#   {'Cities', 'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Decatur_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Dickinson_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated places',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Doniphan_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Douglas_County,_Kansas',
#   {'=Historic Townships=',
#    'Incorporated cities',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Edwards_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Elk_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ellis_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Defunct settlements',
#    'Other unincorporated places',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Jewell_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Johnson_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Kingman_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Labette_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ellsworth_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Finney_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ford_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated places',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Hamilton_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Gove_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Geary_County,_Kansas',
#   {'Cities',
#    'Fort Riley',
#    'Ghost towns',
#    'Townships',
#    'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Jackson_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Graham_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Grant_County,_Kansas',
#   {'City', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Greeley_County,_Kansas',
#   {'Cities', 'Ghost Towns', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Greenwood_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Harper_County,_Kansas',
#   {'Cities', 'Ghost Towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Harvey_County,_Kansas',
#   {'Cities', 'Ghost town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Haskell_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Jefferson_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Kiowa_County,_Kansas',
#   {'Incorporated cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lane_County,_Kansas',
#   {'Census-designated place',
#    'City',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Norton_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Pottawatomie_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Pratt_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Russell_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Seward_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Sheridan_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Stanton_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Trego_County,_Kansas',
#   {'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Leavenworth_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lincoln_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Linn_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Logan_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Lyon_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Osage_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/McPherson_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Marion_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Marshall_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Meade_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Miami_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Mitchell_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Montgomery_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Morris_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Morton_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Thomas_County,_Kansas',
#   {'Census-designated place', 'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Nemaha_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Neosho_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Osborne_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Pawnee_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Phillips_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ness_County,_Kansas',
#   {'Cities', 'Ghost town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Ottawa_County,_Kansas',
#   {'Cities', 'Ghost town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Rawlins_County,_Kansas',
#   {'Incorporated cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Reno_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Republic_County,_Kansas',
#   {'Ghost town', 'Incorporated cities', 'Townships', 'Unincorporated cities'}),
#  ('https://en.wikipedia.org/wiki/Rice_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Rooks_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Riley_County,_Kansas',
#   {'Cities',
#    'Fort Riley',
#    'Ghost towns',
#    'Townships',
#    'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Washington_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Rush_County,_Kansas',
#   {'Cities', 'Former townships', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Saline_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Scott_County,_Kansas',
#   {'City', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Sedgwick_County,_Kansas',
#   {'Census-designated places',
#    'Cities',
#    'Ghost towns',
#    'Townships',
#    'Unincorporated places'}),
#  ('https://en.wikipedia.org/wiki/Shawnee_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost town',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Sherman_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Smith_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Stafford_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Stevens_County,_Kansas',
#   {'Cities', 'Townships', 'Unincorporated community'}),
#  ('https://en.wikipedia.org/wiki/Sumner_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wabaunsee_County,_Kansas',
#   {'Cities', 'Ghost town', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wallace_County,_Kansas',
#   {'Census-designated places', 'Cities', 'Townships'}),
#  ('https://en.wikipedia.org/wiki/Wichita_County,_Kansas',
#   {'City', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Wilson_County,_Kansas',
#   {'Cities', 'Ghost towns', 'Townships', 'Unincorporated communities'}),
#  ('https://en.wikipedia.org/wiki/Woodson_County,_Kansas',
#   {'Census-designated place',
#    'Cities',
#    'Ghost towns',
#    'Other unincorporated communities',
#    'Townships'}),
#  ('https://en.wikipedia.org/wiki/Wyandotte_County,_Kansas',
#   {'Incorporated cities', 'Townships', 'Unincorporated communities'})]

# %% [markdown]
# ---
# #### Newtypes

# %% [markdown]
# ---

# %% [markdown]
# #### Investigations

# %%
def wikipedia_communities_subheadings(text):
    import re

    regex = r"(^==Communities==)(.+?)(^==[^=].+?[^=]==)"
    post_communities = re.findall(regex, text, re.MULTILINE + re.DOTALL)
    
    print(post_communities)
    if len(post_communities) == 0:
        return []

    # print(post_communities[0])
    post_communities = post_communities[0]
    
    regex = r"===(.+)==="
    res = [result.strip() for result in re.findall(regex, post_communities[1])]

    return res

title = 'Prince_of_Wales_%E2%80%93_Hyder_Census_Area,_Alaska'
print(counties_export_text.take(100)[twenty.index(title)])
wikipedia_communities_subheadings(counties_export_text.take(100)[twenty.index(title)])
# Out:
# #REDIRECT [[Prince of Wales–Hyder Census Area, Alaska]]
# {{R from move}}
# []
# []

# %%
def wikipedia_export_get(title):
    xml = http_get("https://en.wikipedia.org/wiki/Special:Export/" + title)
    
    if b'<redirect title' in xml:
        return wikipedia_export_get(title=BeautifulSoup(xml).select('redirect')[0]['title'])
    else:
        return xml
    
print(BeautifulSoup(wikipedia_export_get(title)))
# Out:
# <mediawiki version="0.10" xml:lang="en" xmlns="http://www.mediawiki.org/xml/export-0.10/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd">
# <siteinfo>
# <sitename>Wikipedia</sitename>
# <dbname>enwiki</dbname>
# <base/>https://en.wikipedia.org/wiki/Main_Page
#     <generator>MediaWiki 1.35.0-wmf.41</generator>
# <case>first-letter</case>
# <namespaces>
# <namespace case="first-letter" key="-2">Media</namespace>
# <namespace case="first-letter" key="-1">Special</namespace>
# <namespace case="first-letter" key="0"></namespace>
# <namespace case="first-letter" key="1">Talk</namespace>
# <namespace case="first-letter" key="2">User</namespace>
# <namespace case="first-letter" key="3">User talk</namespace>
# <namespace case="first-letter" key="4">Wikipedia</namespace>
# <namespace case="first-letter" key="5">Wikipedia talk</namespace>
# <namespace case="first-letter" key="6">File</namespace>
# <namespace case="first-letter" key="7">File talk</namespace>
# <namespace case="first-letter" key="8">MediaWiki</namespace>
# <namespace case="first-letter" key="9">MediaWiki talk</namespace>
# <namespace case="first-letter" key="10">Template</namespace>
# <namespace case="first-letter" key="11">Template talk</namespace>
# <namespace case="first-letter" key="12">Help</namespace>
# <namespace case="first-letter" key="13">Help talk</namespace>
# <namespace case="first-letter" key="14">Category</namespace>
# <namespace case="first-letter" key="15">Category talk</namespace>
# <namespace case="first-letter" key="100">Portal</namespace>
# <namespace case="first-letter" key="101">Portal talk</namespace>
# <namespace case="first-letter" key="108">Book</namespace>
# <namespace case="first-letter" key="109">Book talk</namespace>
# <namespace case="first-letter" key="118">Draft</namespace>
# <namespace case="first-letter" key="119">Draft talk</namespace>
# <namespace case="first-letter" key="446">Education Program</namespace>
# <namespace case="first-letter" key="447">Education Program talk</namespace>
# <namespace case="first-letter" key="710">TimedText</namespace>
# <namespace case="first-letter" key="711">TimedText talk</namespace>
# <namespace case="first-letter" key="828">Module</namespace>
# <namespace case="first-letter" key="829">Module talk</namespace>
# <namespace case="first-letter" key="2300">Gadget</namespace>
# <namespace case="first-letter" key="2301">Gadget talk</namespace>
# <namespace case="case-sensitive" key="2302">Gadget definition</namespace>
# <namespace case="case-sensitive" key="2303">Gadget definition talk</namespace>
# </namespaces>
# </siteinfo>
# <page>
# <title>Prince of Wales–Hyder Census Area, Alaska</title>
# <ns>0</ns>
# <id>87485</id>
# <revision>
# <id>964738869</id>
# <parentid>958458205</parentid>
# <timestamp>2020-06-27T08:45:23Z</timestamp>
# <contributor>
# <username>BHGbot</username>
# <id>5737366</id>
# </contributor>
# <minor></minor>
# <comment>[[WP:BHGbot 6]] ([[User:BHGbot/6/List 5|List 5]]): eponymous category first, per [[MOS:CATORDER]]; [[WP:GENFIXES]]</comment>
# <model>wikitext</model>
# <format>text/x-wiki</format>
# <text bytes="9583" xml:space="preserve">{{short description|Census area located in the U.S. state of Alaska}}
# {{Infobox U.S. county
# | county = Prince of Wales-Hyder Census Area&lt;!-- Do NOT change the spelling of the image file! --&gt;
# | state = Alaska
# | ex image = STOREHOUSE NO. 4 IN HYDER.jpg
# | ex image size = 300px
# | ex image cap = [[Hyder, Alaska|Hyder]],  Storehouse No. 4, built by [[David du Bose Gaillard]].
# | seal =
# | founded year = 2008&lt;ref&gt;The census area acquired its current name in 2008, after the Outer Ketchikan was annexed by the Ketchikan Gateway Borough.&lt;/ref&gt;
# | founded date =
# | founded title = Established
# | seat wl =
# | largest city wl = Craig
# | area_total_sq_mi = 7683
# | area_land_sq_mi = 3923
# | area_water_sq_mi = 3760
# | area percentage = 48.9%
# | census estimate yr = 2019
# | pop = 6,203
# | density_sq_mi = 1.42
# | web =
# |named for = [[Prince of Wales Island (Alaska)|Prince of Wales Island]] and [[Hyder, Alaska|Hyder]]
# | district = At-large
# | time zone = Alaska
# }}
#
# '''Prince of Wales–Hyder Census Area''' is a [[census area]] located in the [[U.S. state]] of [[Alaska]]. As of the [[2010 United States Census|2010 census]], the population was 5,559.&lt;ref name="QF"&gt;{{cite web|title=State &amp; County QuickFacts|url=http://quickfacts.census.gov/qfd/states/02/02198.html|publisher=United States Census Bureau|accessdate=May 18, 2014|archive-url=https://web.archive.org/web/20150905201949/http://quickfacts.census.gov/qfd/states/02/02198.html|archive-date=September 5, 2015|url-status=dead}}&lt;/ref&gt; It is part of the [[unorganized borough]] and therefore has no [[borough seat]]. Its largest communities are [[Craig, Alaska|Craig]] and [[Metlakatla, Alaska|Metlakatla]]. It was formerly part of the Census Bureau's '''Prince of Wales–Outer Ketchikan Census Area''', but the name was changed in 2008 after most of the Outer Ketchikan (except the parts near the community of [[Hyder, Alaska|Hyder]], and [[Annette Island]]) was lost to annexation by the [[Ketchikan Gateway Borough, Alaska|Ketchikan Gateway Borough]].
#
# ==Geography==
# [[File:Map of Alaska highlighting Prince of Wales-Outer Ketchikan Census Area.svg|thumb|300px|right|Map of the former Prince of Wales–Outer Ketchikan Census Area]]
#
# According to the [[U.S. Census Bureau]], the census area has a total area of {{convert|7683|sqmi}}, of which {{convert|3923|sqmi}} is land and {{convert|3760|sqmi}} (48.9%) is water.&lt;ref name="GR1"&gt;{{cite web|url=https://www.census.gov/geographies/reference-files/time-series/geo/gazetteer-files.html|publisher=[[United States Census Bureau]]|accessdate=April 23, 2011|date=February 12, 2011|title=US Gazetteer files: 2010, 2000, and 1990}}&lt;/ref&gt; The present-day Prince of Wales–Hyder Census Area includes the Hyder area as an [[exclave]], and Annette Island, which is mostly surrounded by territory of Ketchikan Gateway Borough.&lt;ref&gt;[http://labor.alaska.gov/research/alari/images/maps/5_21_0map.pdf Map: Prince of Wales–Hyder Census Area] {{webarchive|url=https://web.archive.org/web/20090811001831/http://labor.alaska.gov/research/alari/images/maps/5_21_0map.pdf |date=2009-08-11 }} Alaska Department of Labor&lt;/ref&gt; Before the transfer of territory, [[Ketchikan Gateway Borough, Alaska|Ketchikan Gateway Borough]] was [[enclave]]d within (surrounded by) the census area.
#
# ===Adjacent boroughs and census areas===
# * [[Petersburg Borough, Alaska|Petersburg Borough]] – north
# * City and Borough of [[Wrangell, Alaska]] – northeast
# * [[Ketchikan Gateway Borough, Alaska|Ketchikan Gateway Borough]] – between Prince of Wales and Hyder
# * [[Regional District of Kitimat-Stikine|Kitimat-Stikine Regional District, British Columbia]] – east
# * [[Skeena-Queen Charlotte Regional District, British Columbia]] – south (water boundary only, across [[Dixon Entrance]] to [[Hecate Strait]])
#
# ===National protected areas===
# * [[Alaska Maritime National Wildlife Refuge]] (part of Gulf of Alaska unit)
# ** [[Forrester Island Wilderness]]
# * [[Tongass National Forest]] (part)
# ** [[Karta River Wilderness]]
# ** [[Maurille Islands Wilderness]]
# ** [[South Prince of Wales Wilderness]]
# ** [[Warren Island Wilderness]]
#
# ==Demographics==
# {{US Census population
# | 1960= 1772
# | 1970= 2106
# | 1980= 3822
# | 1990= 6278
# | 2000= 6146
# | 2010= 5559
# | estyear=2019
# | estimate=6203
# | estref=&lt;ref name="USCensusEst2018"&gt;{{cite web|url=https://www.census.gov/programs-surveys/popest/data/tables.2018.html|title=Population and Housing Unit Estimates|accessdate=May 11, 2019}}&lt;/ref&gt;
# | align-fn=center
# | footnote=U.S. Decennial Census&lt;ref&gt;{{cite web|url=https://www.census.gov/programs-surveys/decennial-census.html|title=U.S. Decennial Census|publisher=United States Census Bureau|accessdate=May 18, 2014}}&lt;/ref&gt;&lt;br /&gt;1790–1960&lt;ref&gt;{{cite web|url=http://mapserver.lib.virginia.edu|title=Historical Census Browser|publisher=University of Virginia Library|accessdate=May 18, 2014}}&lt;/ref&gt; 1900–1990&lt;ref&gt;{{cite web|url=https://www.census.gov/population/cencounts/ak190090.txt|title=Population of Counties by Decennial Census: 1900 to 1990|publisher=United States Census Bureau|accessdate=May 18, 2014}}&lt;/ref&gt;&lt;br /&gt;1990–2000&lt;ref&gt;{{cite web|url=https://www.census.gov/population/www/cen2000/briefs/phc-t4/tables/tab02.pdf|title=Census 2000 PHC-T-4. Ranking Tables for Counties: 1990 and 2000|publisher=United States Census Bureau|accessdate=May 18, 2014}}&lt;/ref&gt; 2010–2018&lt;ref name="QF" /&gt;
# }}
#
# At the [[2000 United States Census|2000 census]] there were 6,146 people, 2,262 households, and 1,535 families residing in the then-census area.  The population density was 1 people per square mile (0/km²).  There were 3,055 housing units at an average density of 0 persons/km² (0 persons/sq&amp;nbsp;mi).  The [[Race and ethnicity in the United States Census#2000 census|racial makeup]] of the census area was 53.12% [[Race and ethnicity in the United States Census|White]], 0.15% [[Race and ethnicity in the United States Census|African American]], 38.68% [[Race and ethnicity in the United States Census|Native American]], 0.36% [[Race and ethnicity in the United States Census|Asian]], 0.05% [[Race and ethnicity in the United States Census|Pacific Islander]], 0.50% from [[Race and ethnicity in the United States Census|other races]], and 7.14% from two or more races.  [[Race and ethnicity in the United States Census|Hispanic]] or [[Race and ethnicity in the United States Census|Latino]] of any race were 1.74% of any race.&lt;ref name="GR8"&gt;{{cite web|url=https://www.census.gov|publisher=[[United States Census Bureau]] | accessdate=May 14, 2011|title=U.S. Census website}}&lt;/ref&gt;
# Of the 2,262 households 37.60% had children under the age of 18 living with them, 50.80% were married couples living together, 10.00% have a woman whose husband does not live with her, and 32.10% were non-families. 26.00% of households were one person and 5.00% were one person aged 65 or older.  The average household size was 2.68 and the average family size was 3.25.
#
# In the census area the population was spread out with 31.00% under the age of 18, 7.50% from 18 to 24, 30.10% from 25 to 44, 25.80% from 45 to 64, and 5.70% 65 or older.  The median age was 35 years. For every 100 females, there were 119.80 males.  For every 100 females age 18 and over, there were 125.60 males.
#
# ==Communities==
# ===Cities===
# {{Div col|colwidth=15em}}
# *[[Coffman Cove, Alaska|Coffman Cove]]
# *[[Craig, Alaska|Craig]]
# *[[Edna Bay, Alaska|Edna Bay]]
# *[[Hydaburg, Alaska|Hydaburg]]
# *[[Kake, Alaska|Kake]]
# *[[Kasaan, Alaska|Kasaan]]
# *[[Klawock, Alaska|Klawock]]
# *[[Port Alexander, Alaska|Port Alexander]]
# *[[Thorne Bay, Alaska|Thorne Bay]]{{div col end}}
#
# === Census-designated places ===
# {{Div col|colwidth=15em}}
# *[[Hollis, Alaska|Hollis]]
# *[[Hyder, Alaska|Hyder]]
# *[[Metlakatla, Alaska|Metlakatla]]
# *[[Naukati Bay, Alaska|Naukati Bay]]
# *[[Point Baker, Alaska|Point Baker]]
# *[[Port Protection, Alaska|Port Protection]]
# *[[Whale Pass, Alaska|Whale Pass]]{{div col end}}
#
# === Unincorporated Community ===
#
# * [[Waterfall, Alaska|Waterfall]]
#
# ==See also==
# * [[List of airports in Alaska]]
#
# ==References==
# {{reflist|30em}}
#
# ==External links==
# * [http://labor.alaska.gov/research/census/tract/pow.pdf Prince of Wales–Outer Ketchikan Census Area map, 2000 census: Alaska Department of Labor]{{dead link|date=March 2018 |bot=InternetArchiveBot |fix-attempted=yes }}
# * [http://labor.alaska.gov/research/census/borcamaps/5_21_0map.pdf Prince of Wales–Hyder Census Area map, 2010 census: Alaska Department of Labor]{{dead link|date=March 2018 |bot=InternetArchiveBot |fix-attempted=yes }}
# * [https://web.archive.org/web/20141217223547/http://labor.alaska.gov/research/census/maps/bor/02198.pdf Prince of Wales–Hyder Census Area map, January 2014: Alaska Department of Labor]
#
# {{Geographic Location
# | Center    = Prince of Wales–Hyder, Alaska
# | North     = [[Petersburg Census Area, Alaska|Petersburg Census Area]]
# | Northeast = City and Borough of [[Wrangell, Alaska|Wrangell]]
# | East      = [[Ketchikan Gateway Borough, Alaska|Ketchikan Gateway Borough]];&lt;br /&gt;[[Kitimat–Stikine Regional District, British Columbia]], Canada
# | Southeast =
# | South     = [[Skeena-Queen Charlotte Regional District, British Columbia]], Canada
# | Southwest =
# | West      = [[Gulf of Alaska]]
# | Northwest =
# }}
#
# {{Prince of Wales–Hyder Census Area, Alaska}}
# {{Alaska}}
# {{Western U.S. majority-minority counties}}
# {{Coord|55.45|-132.05|display=title|type:adm2nd_region:US-AK_source:UScensus1990_scale:2000000}}
#
# {{authority control}}
#
# {{DEFAULTSORT:Prince of Wales Hyder Census Area, Alaska}}
# [[Category:Prince of Wales–Hyder Census Area, Alaska| ]]
# [[Category:Alaska census areas]]</text>
# <sha1>pucum5cybl988vbf2p8lzvepr3x3qv9</sha1>
# </revision>
# </page>
# </mediawiki>
