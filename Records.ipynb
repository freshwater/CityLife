# %% [markdown]
# ## Records

# %% [markdown]
# ---

# %%
["Municipalities",
 "Cities and communities",
 "Community"
]
# Out:
# ['Municipalities', 'Cities and communities']

# %% [markdown]
# ---
# #### List of "community types"

# %%
counties_export_text.map(wikipedia_communities_subheadings).map(set).reduce(set.union)
# Out:
# {'1910 Census-designated places',
#  '= At night =',
#  '= Census-designated place =',
#  '= Census-designated places =',
#  '= Other unincorporated communities =',
#  '= Unincorporated communities =',
#  '=At night=',
#  '=Brewster=',
#  '=Carmel=',
#  '=Census designated places=',
#  '=Census-designated place=',
#  '=Census-designated places=',
#  '=Cities=',
#  '=City=',
#  '=Civil=',
#  '=Cold Spring=',
#  '=Community councils=',
#  '=Current townships=',
#  '=Current=',
#  '=East Daviess=',
#  '=Former township=',
#  '=Former townships=',
#  '=Ghost Towns=',
#  '=Ghost towns/neighborhoods=',
#  '=Historic Townships=',
#  '=Historic=',
#  '=Historical communities=',
#  '=Kent=',
#  '=Nelsonville=',
#  '=North Livingston=',
#  '=North McLean=',
#  '=North=',
#  '=Northeast Warren=',
#  '=Ohio House Districts=',
#  '=Ohio Senate Districts=',
#  '=Other unincorporated communities=',
#  '=Other villages=',
#  '=Paper=',
#  '=Patterson=',
#  '=Philipstown=',
# ...
